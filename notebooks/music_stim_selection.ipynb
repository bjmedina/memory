# %%
import json
import os

import glob as glob
import numpy as np
import matplotlib.pyplot as plt

from scipy.io.wavfile import write, read

# %%
path_to_stim_1 = "/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/*.wav"
path_to_stim_1_json = "/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/filenames.json"

with open(path_to_stim_1_json) as f:
    stim_1_json = json.load(f)

path_to_stim_2 = "/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/*.wav"
path_to_stim_2_json = "/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/filenames.json"

with open(path_to_stim_2_json) as f:
    stim_2_json = json.load(f)


#print(*glob.glob(path_to_stim), sep='\n')

# %%
#stim_1_json
all_stims = stim_1_json + stim_2_json
nhs_stims = [stim for stim in all_stims if stim['type'] == 'nhs']
global_stims = [stim for stim in all_stims if stim['type'] == 'global-music']

# %%
global_stims[0]
# Out:
# {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_KubrAnJ0o0o.wav',
#  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_1.wav',
#  'filename': 'mem_stim_1.wav',
#  'type': 'global-music'}

# %%
from IPython.display import display, clear_output
import IPython.display as ipd
import random

def batched_selection(stims, keep_list, label="nhs"):
    while len(keep_list) < 46 and stims:
        clear_output(wait=True)
        print(f"Category: {label}")
        print(f"Selected: {len(keep_list)} / 46")
        print("Showing 20 random sounds...\n")

        # Step 1: Choose a batch of up to 20
        batch = random.sample(stims, min(20, len(stims)))

        # Step 2: Display the batch
        for stim in batch:
            print(stim['stim_path'])
            display(ipd.Audio(stim['stim_path']))

        # Step 3: Get user input
        choice = input("\nType a filename to KEEP, 'next' for new batch, or 'exit' to stop: ").strip()

        if choice.lower() == 'exit':
            print("Exiting selection.")
            break
        elif choice.lower() == 'next':
            continue

        # Step 4: Match filename and store if valid
        matched = [s for s in batch if s['stim_path'] == choice]
        if matched:
            keep_list.append(matched[0])
            stims.remove(matched[0])
        else:
            print(f"Filename '{choice}' not found in this batch. Try again.")

    clear_output(wait=True)
    print(f"Done selecting from {label}. Final count: {len(keep_list)}")

# %%
nhs_keep = [{'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-XRSS.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_177.wav',
  'filename': 'mem_stim_177.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-NFZO.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_101.wav',
  'filename': 'mem_stim_101.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-50PO.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_4.wav',
  'filename': 'mem_stim_4.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-CS8N.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_11.wav',
  'filename': 'mem_stim_11.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-GN0J.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_16.wav',
  'filename': 'mem_stim_16.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-4N10.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_157.wav',
  'filename': 'mem_stim_157.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-ZW00.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_105.wav',
  'filename': 'mem_stim_105.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-NGPL.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_78.wav',
  'filename': 'mem_stim_78.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-330H.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_40.wav',
  'filename': 'mem_stim_40.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-5C46.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_93.wav',
  'filename': 'mem_stim_93.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-8SSJ.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_29.wav',
  'filename': 'mem_stim_29.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-A55H.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_103.wav',
  'filename': 'mem_stim_103.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-O8Q2.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_27.wav',
  'filename': 'mem_stim_27.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-XWL8.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_173.wav',
  'filename': 'mem_stim_173.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-CRJW.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_96.wav',
  'filename': 'mem_stim_96.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-R4T4.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_107.wav',
  'filename': 'mem_stim_107.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-LO2V.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_115.wav',
  'filename': 'mem_stim_115.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-AHRQ.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_84.wav',
  'filename': 'mem_stim_84.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-OXV1.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_0.wav',
  'filename': 'mem_stim_0.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-LT6Y.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_147.wav',
  'filename': 'mem_stim_147.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-JYNI.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_172.wav',
  'filename': 'mem_stim_172.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-PC0R.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_130.wav',
  'filename': 'mem_stim_130.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-AOJA.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_95.wav',
  'filename': 'mem_stim_95.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-YCNL.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_33.wav',
  'filename': 'mem_stim_33.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-TFXV.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_77.wav',
  'filename': 'mem_stim_77.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-BJKN.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_35.wav',
  'filename': 'mem_stim_35.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-BHQB.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_40.wav',
  'filename': 'mem_stim_40.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-4KKI.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_151.wav',
  'filename': 'mem_stim_151.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-WZ7J.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_167.wav',
  'filename': 'mem_stim_167.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-BCPU.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_54.wav',
  'filename': 'mem_stim_54.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-O4O6.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_16.wav',
  'filename': 'mem_stim_16.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-Y6V2.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_178.wav',
  'filename': 'mem_stim_178.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-ERSV.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_52.wav',
  'filename': 'mem_stim_52.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-GN0J.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_16.wav',
  'filename': 'mem_stim_16.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-330H.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_40.wav',
  'filename': 'mem_stim_40.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-UDOB.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_2.wav',
  'filename': 'mem_stim_2.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-NGPL.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_78.wav',
  'filename': 'mem_stim_78.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-XRSS.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_177.wav',
  'filename': 'mem_stim_177.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-HRC7.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_89.wav',
  'filename': 'mem_stim_89.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-ZW00.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_105.wav',
  'filename': 'mem_stim_105.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-M00Z.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_179.wav',
  'filename': 'mem_stim_179.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-0CO2.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_141.wav',
  'filename': 'mem_stim_141.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-PC0R.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_130.wav',
  'filename': 'mem_stim_130.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-OXV1.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_0.wav',
  'filename': 'mem_stim_0.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-Y6V2.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_178.wav',
  'filename': 'mem_stim_178.wav',
  'type': 'nhs'},
 {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-LO2V.mp3',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_115.wav',
  'filename': 'mem_stim_115.wav',
  'type': 'nhs'}]

# %%
batched_selection(nhs_stims, nhs_keep, label="nhs")
# Out:
# Done selecting from nhs. Final count: 46

# %%
nhs_keep
# Out:
# [{'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-XRSS.mp3',
#   'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_177.wav',
#   'filename': 'mem_stim_177.wav',
#   'type': 'nhs'},
#  {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-NFZO.mp3',
#   'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_101.wav',
#   'filename': 'mem_stim_101.wav',
#   'type': 'nhs'},
#  {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-50PO.mp3',
#   'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_4.wav',
#   'filename': 'mem_stim_4.wav',
#   'type': 'nhs'},
#  {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-CS8N.mp3',
#   'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_11.wav',
#   'filename': 'mem_stim_11.wav',
#   'type': 'nhs'},
#  {'orig_path': '/om2/user/bjmedina/data/expanded-NHS/NHS2-GN0J.mp3',
# ...

# %%
batched_selection(global_stims, global_keep, label="global-music")
# Out:
# Done selecting from global-music. Final count: 46

# %%
global_keep = [{'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_D9TuP8PKD6M.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_68.wav',
  'filename': 'mem_stim_68.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_HFVM5pVTwkM.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_18.wav',
  'filename': 'mem_stim_18.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_PTLOLz9YzmM.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_94.wav',
  'filename': 'mem_stim_94.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_K1BOsSMEX-I.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_164.wav',
  'filename': 'mem_stim_164.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_F3uf_RleI3E.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_131.wav',
  'filename': 'mem_stim_131.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_2vQTq4QLP8U.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_160.wav',
  'filename': 'mem_stim_160.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_SgZru-X3bqU.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_21.wav',
  'filename': 'mem_stim_21.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_-0Gj8-vB1q4.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_5.wav',
  'filename': 'mem_stim_5.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_BquHBzP5Ep0.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_134.wav',
  'filename': 'mem_stim_134.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_2sIfE3KOi5s.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_140.wav',
  'filename': 'mem_stim_140.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_CN2QSmhP-HI.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_167.wav',
  'filename': 'mem_stim_167.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_KpRHRh9PaRU.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_17.wav',
  'filename': 'mem_stim_17.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_7WZwlOrRELI.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_147.wav',
  'filename': 'mem_stim_147.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_BKmv_mecn5g.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_121.wav',
  'filename': 'mem_stim_121.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_SJFthHp3aI8.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_122.wav',
  'filename': 'mem_stim_122.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_P25JeM4lPGw.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_53.wav',
  'filename': 'mem_stim_53.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_DaO4GigZ51k.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_176.wav',
  'filename': 'mem_stim_176.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_EaGhKzpkNso.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_86.wav',
  'filename': 'mem_stim_86.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_0wM_qR6Yihk.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_50.wav',
  'filename': 'mem_stim_50.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_P240GHf9Eq4.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_142.wav',
  'filename': 'mem_stim_142.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_NJGo2fmUAII.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_101.wav',
  'filename': 'mem_stim_101.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_FE_TIViRu7g.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_136.wav',
  'filename': 'mem_stim_136.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_0L6xco-GIow.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_65.wav',
  'filename': 'mem_stim_65.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_OshyhWVquA0.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_118.wav',
  'filename': 'mem_stim_118.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_P6CmUYzGqN4.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_136.wav',
  'filename': 'mem_stim_136.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_3EtbIWF_ynU.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_11.wav',
  'filename': 'mem_stim_11.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_-WXIhTodJ6M.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_133.wav',
  'filename': 'mem_stim_133.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_IYtQfDsFVfA.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_121.wav',
  'filename': 'mem_stim_121.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_Gh27GlUBQFQ.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_39.wav',
  'filename': 'mem_stim_39.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_1S-y1HNurTo.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_159.wav',
  'filename': 'mem_stim_159.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_HS_ikHx4LIQ.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_130.wav',
  'filename': 'mem_stim_130.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_P97w3AdePgQ.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_114.wav',
  'filename': 'mem_stim_114.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_M-OF_v9TI-U.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_88.wav',
  'filename': 'mem_stim_88.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_7Vjp9y6wvkY.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_178.wav',
  'filename': 'mem_stim_178.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_6w7ByyBuUEI.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_15.wav',
  'filename': 'mem_stim_15.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_CZuH43NPynA.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_90.wav',
  'filename': 'mem_stim_90.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_TWfeaccy68s.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_31.wav',
  'filename': 'mem_stim_31.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_0kQD1P0_KUs.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_99.wav',
  'filename': 'mem_stim_99.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_1WlvXneu6oY.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_175.wav',
  'filename': 'mem_stim_175.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_FjFAKjlNiGk.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_137.wav',
  'filename': 'mem_stim_137.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_QtfIj5cJzYw.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_158.wav',
  'filename': 'mem_stim_158.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_BK2laUCyaH0.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_15.wav',
  'filename': 'mem_stim_15.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_FGukRWCfnO8.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_0.wav',
  'filename': 'mem_stim_0.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_00vYncpl0pk.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_64.wav',
  'filename': 'mem_stim_64.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_EntE6TNmIF4.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p2/mem_stim_31.wav',
  'filename': 'mem_stim_31.wav',
  'type': 'global-music'},
 {'orig_path': '/om/data/public/audioset/wavs/eval_segments_downloads/eval_segments_downloads_0/YT_IciNZa0w-UY.wav',
  'stim_path': '/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_p1/mem_stim_163.wav',
  'filename': 'mem_stim_163.wav',
  'type': 'global-music'}]

# %%
import shutil
def prepare_stimuli(list_a, list_b, out_dir, base_name="mem_stim", json_name="filenames.json"):
    """
    Combines and renames stimuli from two lists, alternating entries (even from list_a, odd from list_b),
    copies files into a new directory, and generates a JSON index file.

    Args:
        list_a (list): First list of dictionaries (assigned even indices)
        list_b (list): Second list of dictionaries (assigned odd indices)
        out_dir (str): Directory to save new stimuli and the JSON
        base_name (str): Base filename prefix (default: 'mem_stim')
        json_name (str): Name of the JSON file to save (default: 'filenames.json')
    """
    os.makedirs(out_dir, exist_ok=True)
    combined = []
    idx = 0
    a_idx, b_idx = 0, 0

    while a_idx < len(list_a) or b_idx < len(list_b):
        if idx % 2 == 0 and a_idx < len(list_a):
            item = list_a[a_idx]
            a_idx += 1
        elif idx % 2 == 1 and b_idx < len(list_b):
            item = list_b[b_idx]
            b_idx += 1
        else:
            idx += 1
            continue

        new_filename = f"{base_name}_{idx}.wav"
        new_stim_path = os.path.join(out_dir, new_filename)

        # Copy the file
        shutil.copy(item['stim_path'], new_stim_path)

        # Construct new entry
        new_entry = {
            'orig_path': item['stim_path'],
            'stim_path': new_stim_path,
            'filename': new_filename,
            'onset': item.get('onset', 0.0),
            'type': item['type']
        }

        combined.append(new_entry)
        idx += 1

    # Save JSON
    json_path = os.path.join(out_dir, json_name)
    with open(json_path, 'w') as f:
        json.dump(combined, f, indent=2)

    print(f"✅ Saved {len(combined)} files to {out_dir}")
    print(f"📝 JSON saved to: {json_path}")

# %%
prepare_stimuli(nhs_keep, global_keep, out_dir="/mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_2025", base_name="mem_stim", json_name="filenames.json")
# Out:
# ✅ Saved 92 files to /mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_2025
# 📝 JSON saved to: /mindhive/mcdermott/www/mturk_stimuli/bjmedina/mem_exp_nhs-global_2025/filenames.json
